# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats 
from scipy import stats

# %%
df = pd.read_csv(r'/Users/aaronlin/Desktop/MLproject/ML2022/data/jan_2021_to_feb_2022_linear_output.csv')

# %%
df_attributes = pd.read_csv(r'/Users/aaronlin/Desktop/MLproject/ML2022/data/hero_attributes.txt', delimiter="\t")
df_attributes
# Out:
#                    Hero Primary Attribute  Base Str  Base Agi  Base Int  \
# 0               Abaddon         Strength         22        23        15
# 1             Alchemist         Strength         25        22        25
# 2    Ancient Apparition     Intelligence         20        20        23
# 3             Anti-Mage          Agility         23        24        12
# 4            Arc Warden          Agility         22        20        24
# ..                  ...               ...       ...       ...       ...
# 118          Windranger     Intelligence         18        17        18
# 119       Winter Wyvern     Intelligence         24        16        26
# 120        Witch Doctor     Intelligence         18        13        22
# 121         Wraith King         Strength         22        18        18
# 122                Zeus     Intelligence         19        11        22
#
#      Str Gain  Agi Gain  Int Gain  Base Dmg  Base Armor  Base Magic Res  \
# ...

# %%
if 'Alchemist' in df.columns:
# Out:
#   File "/var/folders/d1/335rkct13zx_60rbbgcmn8yc0000gn/T/ipykernel_26569/684192936.py", line 1
#     if 'Alchemist' in df.columns:
#                                  ^
# SyntaxError: unexpected EOF while parsing
